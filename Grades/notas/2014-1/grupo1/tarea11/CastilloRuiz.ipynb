# %%
# %pylab inline
import math
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
def funcion(x):
    f = (exp(-x**(2)))/(((x-3)**(2))+(0.01**2))
    return f

# %%
x = linspace(-5 ,5, 100)
y = funcion(x)
plot(x ,y , color='g')
title("$Funcion f(x)$", fontsize=25)

# %%
walk=[]
uno = random.random()*10-5
walk.append(uno)
print walk
# Out:
# [-3.793130875512353]

# %%
for  i  in  range(200000):
    dos = random.random()*10-5
    alpha=funcion(dos)/funcion(walk[-1])
    if alpha >= 1:
        walk.append(dos)
    else:
        beta=random.random()
        if beta <= alpha:
            walk.append(dos)
        else:
            walk.append(walk[-1])

# %%
histograma= hist(walk, bins=100, normed=True )
f = funcion(x) # donde  x es el del linspace
nor= sum(f*(x[1]-x[0]))
plot(x, f/nor,linewidth=1, color='r')
title("$Cadena\ de\ Marcov\ para\ f(x)$", fontsize=20)
