# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
data = loadtxt("data.txt")

# %%
x=data[:,2]
y=data[:,3]

# %%
figure(figsize=(11, 11))
scatter(x, y, s=0.5, c='r')
xlabel("$malvaviscos\ espaciales$", fontsize=30)
ylabel("$unicornios\ surrealistas$", fontsize=30)
title("$\mathrm{El\ Universo\ Cercano,\.MUAJAJA!}$", fontsize=30)
xlim([12, 30])
ylim([25, 40])
# Out:
# (25, 40)
