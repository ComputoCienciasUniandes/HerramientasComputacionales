# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
data = loadtxt("data.txt")

# %%
x=data[:,2]
y=data[:,3]

# %%
figure(figsize(9,9))
scatter(x,y,s=0.5,alpha=0.5,c="b")
xlim(10,35)
ylim(22,40)
title("$\mathrm{Grafica\ Galaxias}$", fontsize=35)
xlabel("$Tiempo\ (s)$", fontsize=35)
ylabel("$Galaxias$", fontsize=35)
tick_params(labelsize=15, colors="b")
