# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
datos = loadtxt("data.txt")

# %%
x= datos[:,2]
y= datos[:,3]

# %%
figure(figsize=(9.5, 9))
axes(axisbg="blue")
scatter(x,y, color="yellow", s = 0.5)
ylim([22, 40])
xlim([12, 30])
title("$Cluster\  raro \ a.k.a \ algo \ que \ hice \ en \ kinder$", fontsize = 19)

xlabel("No tengo la mas remota idea que es esto", fontsize=15)
ylabel("Ni esto", fontsize=18)
tick_params(axis="both", labelsize=12)
