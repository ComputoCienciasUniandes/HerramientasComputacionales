# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
x = np.random.random(1000)
y = np.random.random(1000)

# %%
plt.scatter(x, y)

# %%
figure(figsize=(9.5, 9))
scatter(x, y)
xlabel("$x$", fontsize=30)
ylabel("$y$", fontsize=30)
title("$A\ better\ plot$", fontsize=30)

# %%
X=np.linspace(0,1, 21)
Y=np.linspace(0,1, 21)

# %%
plot(X,Y)
scatter(x,y)

# %%
x=np.linspace(0,10, 21)
y=x**2

# %%
plot(x, y, linestyle="--", linewidth=3.5, c='g')
plot(2*x, y, linestyle="-.", linewidth=3.5, c='r')
# Out:
# (0, 100)

# %%
errorbar(x, X, xerr=0.3, yerr=0.08, linewidth=2.5, label=r"$sin$")
# Out:
# <Container object of 3 artists>

# %%
hist(x, bins=10)
ylim({0,10})
# Out:
# (0, 10)

# %%
x=np.random.normal(0,10, 1000000)
y=np.random.random(1000000)

# %%
data=hist2d(x, y, bins=(200,200))
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x9388320>

# %%
data=loadtxt("data.txt")

# %%
x=data[:,2]
y=data[:,3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b1381c5b0ab3> in <module>()
# ----> 1 x=data[:,2]
#       2 y=data[:,3]
#
# NameError: name 'data' is not defined

# %%
scatter( x, y, s=[1])
xlim({10,30})
ylim({25,35})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-82189e6f84a9> in <module>()
# ----> 1 scatter( x, y, s=[1])
#       2 xlim({10,30})
#       3 ylim({25,35})
#
# NameError: name 'scatter' is not defined
