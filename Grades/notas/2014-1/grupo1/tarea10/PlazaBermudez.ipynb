# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
def expfunc(x):
    return (e**(-x**2))


figure(figsize=(9,9))
graf = linspace(-3, 3, 309)
plot(graf,expfunc(graf), 'r')

# %%
x1 = np.random.rand(100000)*3 -1.5
y1 = np.random.rand(100000)
index = np.where(y1<e**(-x1**2))
x2 = x1[index]
y2 = y1[index]

# %%
figure(figsize=(10,10))
scatter(x1,y1, c='g')
scatter(x2,y2, c='r')

# %%
X = len(x2)  # Numero de puntos dentro de la funcion
Y = len(x1)   # Numero de puntos totales.
