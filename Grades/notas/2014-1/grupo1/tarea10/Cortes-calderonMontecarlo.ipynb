# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
x=np.arange(-2.5, 2.5, 0.1)
y=np.e**(-(x**2))
plot(x,y)

# %%
a = np.random.rand(10000)*5 - 2.5
b = np.random.rand(10000)

# %%
figure(figsize=(9, 9))
scatter(a, b, alpha=0.2, s=10)

# %%
index = np.where(b < exp(-(a**2)))

# %%
d = a[index]
e = b[index]

# %%
figure(figsize=(9,9))
scatter(a,b, c='k')
scatter(d,e, c='b')

# %%
X = len(d)
Y = len(a)

# %%
arearara = 5* float(X)/float(Y)
print "la integral de la funcion es = ", arearara
# Out:
# la integral de la funcion es =  1.773
