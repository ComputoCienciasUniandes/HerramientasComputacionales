# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
x1=np.arange(-3, 3, 0.1)y2=np.e**(-(x1**2))plot(x1, y2)

# %%
x = np.random.rand(10000)*6 - 3y = np.random.rand(10000)*1

# %%
figure(figsize=(9, 9))scatter(x, y, alpha=0.2, s=10, c='r')

# %%
figure(figsize=(9,9))scatter(x, y, c='r')scatter(x1, y2, c='b')

# %%
index = np.where(y<e**(-(x**2)))b=x[index]c=y[index]figure(figsize=(9,9))scatter(x, y, c='r')scatter(b, c, c='b')

# %%
M = len(x)W = len(c)

# %%
area = (float(W)/float(M))*(amax(x)-amin(x))print area
# Out:
# 1.77507619349
