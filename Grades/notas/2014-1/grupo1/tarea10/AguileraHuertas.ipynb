# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
x = np.random.rand(10000)*7-3.5
y = np.random.rand(10000)*1-0.0001

# %%
xe=linspace(-3.5,3.5,1000)
ye=(e**-(xe**2))

figure()
plot(xe,ye)

# %%
scatter(x,y, c='g')
scatter(xe,ye, c='r')

# %%
index = np.where(y<(e**-(x**2)))
xc = x[index]
yc = y[index]

# %%
figure(figsize=(9,9))
scatter(x,y, c='g')
scatter(xc,yc, c='r')

# %%
X1=len(xc)
Y1=len(x)

# %%
s=float(X1)/float(Y1)* 7
print s
# Out:
# 1.7801
