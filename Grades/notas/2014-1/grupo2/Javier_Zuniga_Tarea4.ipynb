# %%
# %pylab inline
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
from matplotlib.colors import colorConverter
datos = np.loadtxt('data.txt')
x = datos[:,4]
y = datos[:,3]
figure(figsize=(9, 9))
cmap=cm.RdBu
plt.scatter(x, y, c= 'y' )
plt.xlim(-1,66)
plt.ylim(-1,70)
plt.xlabel('Columna 4')
plt.ylabel('Columna 3')
title("La grafica de los CHAMPIONS", fontsize=30)
text(5, 65, "$\mathrm{ este\ es\ el\ grupo\ de\ los\ Champions}$", fontsize=25)


y = np.arange(65)
z =  y+y[:,np.newaxis]

for i in xrange(1):
    if i==0:
        p = plt.imshow(z)
        fig = plt.gcf()
        plt.clim()   
        
    else:
        z = z + 1
        p.set_data(y)
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.
