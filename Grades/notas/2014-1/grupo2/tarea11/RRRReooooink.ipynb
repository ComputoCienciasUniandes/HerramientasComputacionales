# %%
# %pylab inline
from scipy.interpolate import interp1d
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
t = np.linspace(0, 2*pi, 800)
r = np.linspace(1.2*pi, 1.8*pi, 800)
x =  cos (t)
y = sin(t)
xchiqiz = 0.4*cos (t)-0.5 
ychiqiz = 0.4*sin(t) 
xojochiqiz = 0.2*cos (t)-0.5 
yojochiqiz = 0.4*sin(t) 
xchiqder = 0.4*cos (t)+0.5 
ychiqder = 0.4*sin(t) 
xojochiqder = 0.2*cos (t)+0.5 
yojochiqder = 0.4*sin(t) 
xfeliz = cos (r)
yfeliz = sin (r)+0.15
naricitax = .3*cos (t)
naricitay = 0.1*sin(t)-0.5

# %%
figure(figsize=(7,7))
plot(x, y)
plot (xchiqiz, ychiqiz, linestyle ='--')
plot (xojochiqiz, yojochiqiz)
plot (xojochiqder, yojochiqder)
plot (xchiqder, ychiqder, linestyle ='--')
plot (naricitax, naricitay)
plot(xfeliz, yfeliz)
arrow (-sqrt(3)/2 ,0.5, 0, 0.3)
arrow (-sqrt(3)/2 ,0.8, 0.26, 0)
arrow (sqrt(3)/2 ,0.5, 0, 0.3)
arrow (sqrt(3)/2 ,0.8, -0.26, 0)

arrow (-2 ,2, 0, 2)
arrow (2 ,2, 0, 2)

# %%
# Out:
#   File "<ipython-input-74-62b9ac2c88d2>", line 1
#     interpoladito = interp1d(x,y, kind 'quadratic')
#                                                  ^
# SyntaxError: invalid syntax
