# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
import numpy as np

# %%
from scipy.optimize import curve_fit

# %%
import matplotlib.pyplot as plt

# %%
data= np.loadtxt("data1.dat", delimiter = ' ')

# %%
x=data[0:,0]
y=data[0:,1]
plt.scatter(x,y)

# %%
def expfunc(x,a,b):
    return a*e**(x-b)
fitpars, covmat = curve_fit(expfunc,x,y)

plot(x, expfunc(x, fitpars[0], fitpars[1]), 'r-')
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
scatter(x, y)

# %%
def R2(xexp, xteo):
    EE = sum((xteo-xexp)**2)
    mean = sum(xexp)/(len(xexp))
    variance = sum((mean-xexp)**2)
    R2 = 1 - EE/variance
    return R2

# %%
yteo  = fitpars[0]*e**(x-fitpars[1])
R2(y, yteo)
# Out:
# 0.8486151928093747

# %%
data2= np.loadtxt("data2.dat", delimiter = ' ')

# %%
e=data2[0:,0]
f=data2[0:,1]
plt.scatter(e,f)

# %%
fit = polyfit(e, f, 2)

plot(e, fit[0]*e**2 + fit[1]*e + fit[2], linewidth=2.5)
scatter(e, f, c='k')
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
yteo1 = fit[0]*e**2 + fit[1]*e + fit[2]
R2(f, yteo1)
# Out:
# 0.90036169399295862

# %%
R2(f, yteo1)
# Out:
# 0.90036169399295862

# %%
data3= np.loadtxt("data3.dat", delimiter = ' ')

# %%
g=data3[0:,0]
h=data3[0:,1]
plt.scatter(g,h)

# %%
def plfunc(g,a,b):
    return a*g+b
fitpars, covmat = curve_fit(plfunc,g,h)
plot(g, plfunc(g, fitpars[0], fitpars[1]), 'r-')
scatter(g, h)
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
yteo2 = fit[0]*g+fit[1]

# %%
R2(g, yteo2)
# Out:
# 0.92419409495474025

# %%
data4= np.loadtxt("data4.dat", delimiter = ' ')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-e126a26a3c41> in <module>()
# ----> 1 data4= np.loadtxt("data4.dat", delimiter = ' ')
#
# /usr/lib64/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     794                 vals = [vals[i] for i in usecols]
#     795             # Convert each value according to its column and store
# --> 796             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     797             # Then pack it according to the dtype's nesting
#     798             items = pack_items(items, packing)
#
# ValueError: could not convert string to float: <!DOCTYPE

# %%
l=data4[0:,0]
m=data4[0:,1]
plt.scatter(l,m)

# %%
def sinfunc(l,a,b):
    return a*np.sin(4.0l-b)
fitpars, covmat = curve_fit(sinfunc,l,m)

plot(l, sinfunc(l, fitpars[0], fitpars[1]), 'r-')
scatter(l, m)
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
print fitpars, covmat
yteo3= (fit[0]*(np.sin(4-0*l-fit[1])))

# %%
R2(l, yteo3)
