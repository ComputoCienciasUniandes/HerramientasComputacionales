# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
def R2(xexp, xteo):
    EE = sum((xteo-xexp)**2)
    mean = sum(xexp)/(len(xexp))
    variance = sum((mean-xexp)**2)
    R2 = 1 - EE/variance
    return R2

# %%
dato1=loadtxt("data1.dat")
dato2=loadtxt("data2.dat")
dato3=loadtxt("data3.dat")
dato4=loadtxt("data4.dat")
r=dato1[:,0]
s=dato1[:,1]
t=dato2[:,0]
v=dato2[:,1]
w=dato3[:,0]
x=dato3[:,1]
y=dato4[:,0]
z=dato4[:,1]

figure(figsize=(20, 16))
subplots_adjust(hspace=0.00, wspace=0.00)
subplot(221)
scatter(r,s,c='r')
xlabel("$\mathrm{r}$", fontsize=25)
ylabel("$\mathrm{s}$", fontsize=25)
plot(r, fit[0]*r**2 + fit[1]*r + fit[2], linewidth=2.0)
steo = fit[0]*r**2 + fit[1]*r + fit[2]
R2(s, steo)

subplot(222)
scatter(t,v,c='y')
xlabel("$\mathrm{t}$", fontsize=25)
ylabel("$\mathrm{v}$", fontsize=25)
plot(t, fit[0]*t**2 + fit[1]*t + fit[2], linewidth=2.0)
vteo = fit[0]*t**2 + fit[1]*t + fit[2]
R2(v, vteo)

subplot(223)
scatter(w,x, c='g')
xlabel("$\mathrm{w}$", fontsize=25)
ylabel("$\mathrm{x}$", fontsize=25)
plot(w, fit[0]*w**2 + fit[1]*w + fit[2], linewidth=2.0)
xteo = fit[0]*w**2 + fit[1]*w + fit[2]
R2(x, xteo)

subplot(224)
scatter(y,z, c='b')
xlabel("$\mathrm{y}$", fontsize=25)
ylabel("$\mathrm{z}$", fontsize=25)
plot(y, fit[0]*y**2 + fit[1]*y + fit[2], linewidth=2.0)
zteo = fit[0]*y**2 + fit[1]*y + fit[2]
R2(z, zteo)
# Out:
# -23939472.47208643

# %%
# Out:
# 0.60809338981278804
