# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
from scipy.optimize import curve_fit

# %%
data1 = loadtxt("data1.dat")

# %%
x = data1[:,0]
y = data1[:,1]

# %%
scatter(x, y, c='k', alpha=1, s=50)
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)

# %%
def expfunc(x,a,b):
    return a*e**(x-b)
fitpars, covmat = curve_fit(expfunc,x,y)

plot(x, expfunc(x, fitpars[0], fitpars[1]), 'r-')
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
scatter(x, y)

# %%
def R2(xexp, xteo):
    EE = sum((xteo-xexp)**2)
    mean = sum(xexp)/(len(xexp))
    variance = sum((mean-xexp)**2)
    R2 = 1 - EE/variance
    return R2

# %%
yteo  = fitpars[0]*e**(x-fitpars[1])
R2(y, yteo)
# Out:
# 0.8486151928093747

# %%
data2 = loadtxt("data2.dat")

# %%
data3 = loadtxt("data3.dat")

# %%
data4 = loadtxt("data4.dat")

# %%
x = data2[:,0]
y = data2[:,1]

# %%
scatter(x, y, c='k', alpha=1, s=50)
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)

# %%
fit = polyfit(x, y, 2)

plot(x, fit[0]*x**2 + fit[1]*x + fit[2], linewidth=2.5)
scatter(x, y, c='k')
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
yteo = fit[0]*x**2 + fit[1]*x + fit[2]
R2(y, yteo)
# Out:
# 0.90036169399295862

# %%
x = data3[:,0]
y = data3[:,1]

# %%
scatter(x, y, c='k', alpha=1, s=50)
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)

# %%
fit = polyfit(x, y, 2)

plot(x, fit[0]*x**2 + fit[1]*x + fit[2], linewidth=2.5)
scatter(x, y, c='k')
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
yteo = fit[0]*x**2 + fit[1]*x + fit[2]
R2(y, yteo)
# Out:
# 0.56034599774979776

# %%
x = data4[:,0]
y = data4[:,1]

# %%
scatter(x, y, c='k', alpha=1, s=50)
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)

# %%
def cosfunc(x,a,b):
    return (a*np.cos(2*x-b))**6
fitpars, covmat = curve_fit(cosfunc,x,y)

plot(x, cosfunc(x, fitpars[0], fitpars[1]), 'r-')
scatter(x, y)
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
print fitpars, covmat
# Out:
# [ 1.0328768   1.58921508] [[  4.75461722e-05   2.60809359e-12]
#  [  2.60809359e-12   4.90242798e-04]]
