# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
data=loadtxt("data3.dat")

# %%
from scipy.optimize import curve_fit

# %%
x=data[:,0]
y=data[:,1]

# %%
scatter(x,y)

# %%
fit =  polyfit(x, y, 1)

m=fit[0]
b=fit[1]
x1 = linspace(0, 10, 100)
y1=m*x1+b
plot(x1,y1)
scatter(x,y)
h3=R2(y,y1)

print "Ecuacion=", m,"*x+",b
print "R2=",h3
# Out:
# Ecuacion= -1.91167982507 *x+ -6.39012869845
# R2= 0.560345973772

# %%
def R2(xexp, xteo):
    EE = sum((xteo-xexp)**2)
    mean = sum(xexp)/(len(xexp))
    variance = sum((mean-xexp)**2)
    R2 = 1 - EE/variance
    return R2

# %%
R2(y,y1)
# Out:
# 0.56034597377247897

# %%
data1=loadtxt("data1.dat")

# %%
xd1=data1[:,0]
yd1=data1[:,1]

# %%
scatter(xd1,yd1)

# %%
fit1= curve_fit(expfunc,xd1,yd1)
fit1[0]=a
fit1[1]=b

ye=a*e**(b*x1)
plot(x1,ye)
scatter(xd1,yd1)
r1=R2(yd1,ye)


print "Ecuacion=", a2,"*e**",b2,"*x1"
print "R2=",r1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-d5b0b7f4489d> in <module>()
# ----> 1 fit1= curve_fit(expfunc,xd1,yd1)
#       2 fit1[0]=a
#       3 fit1[1]=b
#       4
#       5 ye=a*e**(b*x1)
#
# NameError: name 'expfunc' is not defined

# %%
data2=loadtxt("data2.dat")

# %%
xd2=data2[:,0]
yd2=data2[:,1]

# %%
scatter(xd2,yd2)

# %%
fit2 = polyfit(xd2, yd2, 4)
a2=fit2[0]
b2=fit2[1]
c2=fit2[2]
d2=fit2[3]
e2=fit2[4]
yp=a2*x1**4+b2*x1**3+c2*x1**2+d2*x1+e
scatter(xd2,yd2)
plot(x1,yp)
h=R2(yd2,yp)


print "Ecuacion=", a2,"*x1**4+",b2,"*x1**3+",c2,"*x1**2+",d2,"*x1+",e
print "R2=",h
# Out:
# Ecuacion= 0.00274301120706 *x1**4+ -0.0101659591262 *x1**3+ 0.757860693962 *x1**2+ 0.741358316108 *x1+ 2.71828182846
# R2= 0.870229180199

# %%
data4=loadtxt("data4.dat")

# %%
xd4=data4[:,0]
yd4=data4[:,1]

# %%
scatter(xd4,yd4)

# %%
fit4= curve_fit(sinfunc,xd4,yd4)
fit4[0]=a4
fit4[1]=b4
plot(x1, sinfunc(x1, a4, b4))
scatter(xd4,yd4)
h4=R2(yd4,sinfunc(x1, a4, b4))
print "R2=",h4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-1906216713fb> in <module>()
# ----> 1 fit4= curve_fit(sinfunc,xd4,yd4)
#       2 fit4[0]=a4
#       3 fit4[1]=b4
#       4 plot(x1, sinfunc(x1, a4, b4))
#       5 scatter(xd4,yd4)
#
# NameError: name 'sinfunc' is not defined
