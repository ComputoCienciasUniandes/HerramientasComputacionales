# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
from scipy.optimize import curve_fit

# %%
data1 = loadtxt('data1.dat')
data2 = loadtxt('data2.dat')
data3 = loadtxt('data3.dat')
data4 = loadtxt('data4.dat')

# %%
x1 = data1[:,0]
y1 = data1[:,1]
x2 = data2[:,0]
y2 = data2[:,1]
x3 = data3[:,0]
x4 = data4[:,0]
y3 = data3[:,1]
y4 = data4[:,1]

# %%
scatter(x1,y1)

# %%
scatter(x2,y2)

# %%
scatter(x3,y3)

# %%
scatter(x4,y4)

# %%
def Exp(x1,a,b):
    return a*e**(x1-b)

fitpars1,covmat1 = curve_fit(Exp,x1,y1)
plot(x1,Exp(x1,fitpars1[0],fitpars1[1]),label="Fit1",linewidth=2,color='g')
scatter(x1,y1,c='b',marker='<')
legend(loc='upper left')

# %%
fit2 = polyfit(x2,y2,2)

plot(x2,fit2[0]*x1**2+fit2[1]*x1+fit2[2],label="Fit2",linewidth=4,color='g')
scatter(x2,y2,c='b')
legend(loc='upper left')

# %%
fit3=polyfit(x3,y3,1)
plot(x3,fit3[0]*x3+fit3[1], label="Fit1", linewidth=2,color='g')
scatter(x3,y3,c='b',marker='^')
legend(loc='upper right')

# %%
def R2(xexp, xteo):
    EE = sum((xteo-xexp)**2)
    mean = sum(xexp)/(len(xexp))
    variance = sum((mean-xexp)**2)
    R2 = 1 - EE/variance
    return R2

# %%
def Cos(x4,a,b,c):
    return a*(np.cos(2*b*x4-c)**2)

fitpars2, covmat2 = curve_fit(Cos,x4,y4)
plot(x4,Cos(x4, fitpars2[0], fitpars2[1], fitpars2[2]),c='g', label='Fit4')
scatter(x4,y4,c='b',marker='>') 
legend(loc='upper left')
print fitpars2[2],fitpars2[1],fitpars2[0]
# Out:
# 1.56605880096 0.998774765475 0.998325771086

# %%
Y1teo=Exp(x1,fitpars1[0],fitpars1[1])

# %%
Y2teo=fit2[0]*(x2**2) + fit2[1]*x2 + fit2[2]

# %%
Y3teo=fit3[0]*x3+fit3[1]

# %%
Y4teo=Cos(x4,fitpars2[0],fitpars2[1],fitpars2[2])

# %%
R2(y1,Y1teo)
# Out:
# 0.8486151928093747

# %%
R2(y2,Y2teo)
# Out:
# 0.90036169399295862

# %%
R2(y3,Y3teo)
# Out:
# 0.56034597377252071

# %%
R2(y4,Y4teo)
# Out:
# 0.92438223358823435
