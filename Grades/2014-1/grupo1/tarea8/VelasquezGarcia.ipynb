# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
data1=loadtxt('data1.dat')

# %%
x1=data1[:,0]
y1=data1[:,1]

# %%
scatter(x1,y1)

# %%
data2 = loadtxt('data2.dat')
data3 = loadtxt('data3.dat')
data4 = loadtxt('data4.dat')

# %%
x2 = data2[:,0]
y2 = data2[:,1]
x3 = data3[:,0]
x4 = data4[:,0]
y3 = data3[:,1]
y4 = data4[:,1]

# %%
fit2 = polyfit(x2,y2,2)

plot(x,fit2[0]*x**2+fit2[1]*x+fit2[2],label="Fit2",linewidth=4,color='g')
scatter(x2,y2,c='b')
legend(loc='left')

# %%
def R2(xexp, xteo):
    EE = sum((xteo-xexp)**2)
    mean = sum(xexp)/(len(xexp))
    variance = sum((mean-xexp)**2)
    R2 = 1 - EE/variance
    return R2

# %%
Y2teo=fit2[0]*(x**2) + fit2[1]*x + fit2[2]

# %%
R2(y2,Y2teo)
# Out:
# -10.06647547000378

# %% [markdown]
# Nicolas, el r² esta hipper loco pero es su codigo
