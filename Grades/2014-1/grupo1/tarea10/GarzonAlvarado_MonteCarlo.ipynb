# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
x=np.arange(-3,3,0.1)
y=e**(-(x**2))
plot(x,y)

# %%
x=np.random.rand(10000)*9-4.5
y=np.random.rand(10000)
plot(x,y)

# %%
index = np.where(y<e**(-(x**2)))

# %%
a=x[index]
b=y[index]

# %%
figure(figsize=(9,9))
scatter(x,y, c='g')
scatter(a,b, c='r')

# %%
F=len(a)
G=len(x)
#9 es el largo del cuadrado
rpi=9*(float(F)/float(G))
print rpi
# Out:
# 1.7739
