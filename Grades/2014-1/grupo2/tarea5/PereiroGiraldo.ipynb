# %%
import numpy as np

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
data= np.loadtxt('data.txt')

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
x=data[:,2]
y=data[:,3]

# %%
figure(figsize=(12, 12))
plt.scatter(x, y, c='c')
plt.xlabel("$Xc$", fontsize=35, color=  '#FF8900')
plt.ylabel("$Yc$", fontsize=35, color=  '#FF8900')
plt.title("Grafica Yc vs Xc", fontsize=45, color=  '#663300')
plt.xlim([14,30])
plt.ylim([22, 38])
plt.colors()
