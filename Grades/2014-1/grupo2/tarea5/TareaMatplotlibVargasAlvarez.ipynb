# %%
import matplotlib.pyplot as plt
import numpy as np
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
a = np.loadtxt("data.txt")

# %%
print a
# Out:
# [[  5.18223400e+06   5.20861700e+06   2.00097693e+01 ...,   8.54703000e+17
#    -1.59036000e+18   5.57950000e-02]
#  [  3.35665300e+06   3.35665300e+06   2.11395456e+01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  3.23678500e+06   3.23857700e+06   1.69059058e+01 ...,   3.06672000e+17
#    -5.71614000e+17   1.89360000e-02]
#  ...,
#  [  1.01000000e+02   1.01000000e+02   2.17481817e+01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  1.01000000e+02   1.01000000e+02   1.66508024e+01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  1.01000000e+02   1.01000000e+02   2.51677510e+01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]]

# %%
x = a[:,2]
y = a[:,3]

# %%
figure(figsize=(20,20))
xlim([12, 32])
ylim([23, 41])
plt.scatter(x, y, c="g", s=70)
xlabel("tercera columna(x)", fontsize=50)
ylabel("cuarta columna(y)", fontsize=50)
title("Tarea matplotlib",fontsize=80)
