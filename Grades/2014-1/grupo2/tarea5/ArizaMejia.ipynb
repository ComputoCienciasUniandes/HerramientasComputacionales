# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
np.loadtxt('data.txt')
# Out:
# array([[  5.18223400e+06,   5.20861700e+06,   2.00097693e+01, ...,
#           8.54703000e+17,  -1.59036000e+18,   5.57950000e-02],
#        [  3.35665300e+06,   3.35665300e+06,   2.11395456e+01, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  3.23678500e+06,   3.23857700e+06,   1.69059058e+01, ...,
#           3.06672000e+17,  -5.71614000e+17,   1.89360000e-02],
#        ...,
#        [  1.01000000e+02,   1.01000000e+02,   2.17481817e+01, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  1.01000000e+02,   1.01000000e+02,   1.66508024e+01, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  1.01000000e+02,   1.01000000e+02,   2.51677510e+01, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00]])

# %%
data = np.loadtxt('data.txt')

# %%
data[0]
# Out:
# array([  5.18223400e+06,   5.20861700e+06,   2.00097693e+01,
#          3.02869974e+01,   2.67453346e+01,   6.65500000e+01,
#          3.92820000e+02,  -1.46070000e+02,   1.23089000e+13,
#          4.74630000e+02,   3.85020000e+02,   9.76400000e+01,
#          3.83030000e+02,   5.33950000e-02,  -3.02700000e-01,
#          5.34000000e-01,   7.89500000e-01,   1.00000000e+00,
#          3.11450000e-02,   9.45539000e-01,  -3.24016000e-01,
#          8.82850000e-01,   4.25607000e-01,   2.80770000e-01,
#          8.60248000e-01,   8.62727000e-01,   9.04372000e-01,
#         -1.64696000e-01,  -3.93684000e-01,   3.54910000e+02,
#          5.81800000e+02,   3.80000000e+01,   9.02937000e+17,
#         -1.64491000e+18,   3.58422680e+02,   8.64379000e+00,
#          4.95847000e+01,   5.55140000e-02,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
# ...

# %%
data[:,0]
# Out:
# array([  5.18223400e+06,   3.35665300e+06,   3.23678500e+06, ...,
#          1.01000000e+02,   1.01000000e+02,   1.01000000e+02])

# %%
x = data[:,2]

# %%
x
# Out:
# array([ 20.00976926,  21.13954565,  16.9059058 , ...,  21.74818168,
#         16.65080236,  25.16775105])

# %%
y = data[:,3]

# %%
y
# Out:
# array([ 30.28699742,  33.53905695,  33.6723606 , ...,  30.92758327,
#         31.47756381,  33.30613432])

# %%
plt.scatter(x,y)

# %%
figure(figsize=(20,20))
plt.scatter(x,y, c='r')
plt.xlim(14, 30)
plt.ylim(23, 40)
plt.xlabel("X$c$", fontsize=30, color='g')
plt.ylabel("Y$c$", fontsize=30, color='g')
title("Grafica datos tarea", fontsize=30, color ='b')

# %%
figure(figsize=(20, 20))
tick_params(axis="both", labelsize=20)
data = hist2d(x, y, bins=(2500, 2500))
xlim(14, 30)
ylim(23, 40)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x62f7830>
