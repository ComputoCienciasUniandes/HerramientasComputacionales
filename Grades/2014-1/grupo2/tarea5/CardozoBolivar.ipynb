# %%
import sys

# %%
sys.version_info
# Out:
# sys.version_info(major=2, minor=7, micro=6, releaselevel='final', serial=0)

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data = np.loadtxt('data.txt')

# %%
x,y = data[:,2], data[:,3]

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.scatter(x,y) #La mas simple de las graficas#

# %%
figure(figsize=(6, 9))
scatter(x, y)
xlabel("Columna $3$", fontsize=30)
ylabel("Columna $4$", fontsize=30)
tick_params(axis="both", labelsize=15)
title("$\mathrm{Jugando \\ con \\ los \\ datos!}$", fontsize=30)

# %%
figure(figsize=(9, 9))
tick_params(axis="both", labelsize=10)
data = hist2d(x, y, bins=(700, 200))
xlabel("Columna $3$", fontsize=15)
ylabel("Columna $4$", fontsize=15)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x0000000015664988>
