# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data = np.loadtxt('data.txt')

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
x = data[:, 2]
y = data[:, 3]

# %%
figure(figsize = (17, 10))
plt.scatter(x, y, c='#00ccff')
plt.xlabel("$Xc$", fontsize=30, color='#339900')
plt.ylabel("$Yc$", fontsize=30, color='#339900')
plt.title("Grafica data", fontsize=45, color='#ff9966', fontname='serif')
plt.xlim([13, 30])
plt.ylim([22, 41])
# Out:
# (22, 41)
