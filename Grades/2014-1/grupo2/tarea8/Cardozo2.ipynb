# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np

# %%
import scipy as sp

# %%
import matplotlib as mp

# %%
data = np.loadtxt('data1.dat')

# %%
scatter(data[:,0],data[:,1])

# %%
from scipy.optimize import curve_fit

# %%
x = data[:,0]
y = data[:,1]
def expfunc(x,a,b):
    return a*e**(x-b)
fitpars, covmat = curve_fit(expfunc,x,y)

# %%
plot(x, expfunc(x, fitpars[0], fitpars[1]), 'r-')
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
scatter(x, y)

# %% [markdown]
# #### Para esta aproximacion de curva, la ecuacion de la funcion es: 1.68251679*e**(x-1.19179788) con un R2 de 0.8486151928093747

# %%
fitpars
# Out:
# array([ 0.94275021,  0.61255321])

# %%
def xteoricos(x):
    y = fitpars[0]*e**(x-fitpars[1])
    return y

# %%
yteoricos = xteoricos(data[:,0])

# %%
def R2(xexp, xteo):
    EE = sum((xteo-xexp)**2)
    mean = sum(xexp)/(len(xexp))
    variance = sum((mean-xexp)**2)
    R2 = 1 - EE/variance
    return R2

# %%
R2(data[:,1],yteoricos)
# Out:
# 0.8486151928093405

# %% [markdown]
# # Data2

# %%
data = np.loadtxt('data2.dat')

# %%
scatter(data[:,0],data[:,1])

# %%
x = data[:,0]
y = data[:,1]
fit = polyfit(x, y, 2)

# %%
plot(x, fit[0]*x**2 + fit[1]*x + fit[0], linewidth=2.5)
scatter(x, y, c='k')
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
yteo = fit[0]*x**2 + fit[1]*x + fit[2]

# %%
R2(y, yteo)
# Out:
# 0.90036169399295862

# %%
fit
# Out:
# array([ 1.07676926, -1.15480218,  9.93111392])

# %% [markdown]
# ### Con lo que vemos que esta distribucion de datos es una curva de la forma: y = 1.07x**2 -1.15x + 9.93

# %% [markdown]
# # Data3

# %%
data = np.loadtxt('data3.dat')

# %%
scatter(data[:,0],data[:,1])

# %%
x = data[:,0]
y = data[:,1]
fit = polyfit(x, y, 1)

# %%
plot(x, fit[0]*x + fit[1], linewidth=2.5)
scatter(x, y, c='k')
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
yteo = fit[0]*x + fit[1]
R2(y, yteo)
# Out:
# 0.56034597377252082

# %%
fit
# Out:
# array([-1.91167983, -6.3901287 ])

# %%
R2(data[:,1],yteo)
# Out:
# 0.56034597377252082

# %% [markdown]
# ### Lo que muestra dos cosas. Primero que la funcion que mas se acopla a mis datos, es una funcion lineal que es de la forma: y =  -1.9111x - 6.39

# %%
data = np.loadtxt('data4.dat')

# %%
scatter(data[:,0],data[:,1])

# %%
x = data[:,0]
y = data[:,1]
def sinfunc(x,a,b,c,d):
    return a*np.sin(b*x - c) - d
fitpars, covmat = curve_fit(sinfunc,x,y)

# %%
plot(x, sinfunc(x, fitpars[0], fitpars[1],fitpars[2],fitpars[3],))
scatter(x, y)
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
print fitpars, covmat
# Out:
# [-0.03526853  1.62725695 -2.93360521 -0.48710281] [[  2.96947606e-03  -2.42227377e-03  -1.07295648e-02  -3.52525678e-04]
#  [ -2.42227377e-03   3.16143979e-01   1.42054840e+00   2.81528684e-04]
#  [ -1.07295648e-02   1.42054840e+00   8.74671004e+00  -2.86311822e-03]
#  [ -3.52525678e-04   2.81528684e-04  -2.86311822e-03   1.49742199e-03]]

# %%
fitpars
# Out:
# array([-0.00936265, -0.34950098, -0.49313395])
