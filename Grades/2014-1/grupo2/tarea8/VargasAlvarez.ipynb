# %%
# %pylab inline
from scipy.optimize import curve_fit as cfit
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
a = loadtxt("data1.dat.1")

# %%
k = a[:,0]
j = a[:,1]
scatter(k, j)

# %%
figure(figsize=(10, 10))
x = linspace(0, 10, 30)
y = e**x
def expfunc(x,a,b):
    return a*e**(x-b)
fit, covmat = cfit(expfunc,x,y)

plot(x, expfunc(x, fit[0], fit[1]), 'r-')
scatter(k, j)
fit[0], fit[1]
# Out:
# (1.8827579283077249, 0.63273768501567362)

# %% [markdown]
# $y=1,88e(x-0.63)$

# %%
# Out:
# (1.8827579283077249, 0.63273768501567362)
