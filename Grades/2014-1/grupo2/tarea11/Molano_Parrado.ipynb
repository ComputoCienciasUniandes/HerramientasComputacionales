# %%
# %pylab inline
import math
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
def caca(x):
    y = exp(-(x**2))/((x-3)**2 + (0.01)**2)
    return y

# %%
X = linspace(-10, 10, 500)
Y = caca(X)

# %%
plot(X, Y)

# %%
walk = []
x = random.random()*10
walk.append(x)

# %%
for i in range(200000):
    x = random.random()*2-1 
    alpha = caca(walk[-1] + x)/caca(walk[-1])
    if alpha>=1.0:
        walk.append(walk[-1] + x)
    else:
        beta = random.random()
        if(beta<=alpha):
            walk.append(walk[-1] +  x)
        else:
            walk.append(walk[-1])

# %%
figure(figsize=(12, 8))
histo = hist(walk, bins=40, normed=True, color='y')
caquita = function(X)
norm = sum(caquita*(X[1]-X[0]))
plot(X,caquita/norm, linewidth=1, color='m')
xlabel("$x$", fontsize=30)
ylabel("$y$", fontsize=30)
xlim([-3, 4])
ylim([0, 1.7])
# Out:
# (0, 1.7)
