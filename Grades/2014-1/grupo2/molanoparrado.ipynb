# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
Z = np.loadtxt('caca.txt')

# %%
x = Z[0:4]
y = Z[0:4]

# %%
scatter(x, y)
xlabel("trabajo", fontsize=30)
ylabel("tiempo", fontsize=30)
title("estudiante", fontsize=30)
xlim([0, 1000])
ylim([0, 1000])
# Out:
# (0, 1000)
