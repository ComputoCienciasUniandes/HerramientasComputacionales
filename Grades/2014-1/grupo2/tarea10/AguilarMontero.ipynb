# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x=random.rand(10000)*6-3
y=random.rand(10000)*1

# %%
index = where(y<exp(-(x**2)))
xc=x[index]
yc=y[index]

scatter(x,y, c="g")
scatter(xc,yc, c="b")

# %%
E=len(xc)
REC=len(x)

minx=amin(x)
maxx=amax(x)

areae=float((E)/float(REC))*(maxx-minx)

print areae1
# Out:
# 1.79514991565
