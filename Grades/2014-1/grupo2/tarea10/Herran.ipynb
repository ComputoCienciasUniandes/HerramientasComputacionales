# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
x = np.random.rand(100000)*6-3
y = np.random.rand(100000) 

figure(figsize=(9, 9))


scatter(x,y)

# %%
index= np.where(y<e**-x**2)

X1 = x[index]
Y1 = y[index]

figure(figsize=(9,9))
xlim(-3,3)
ylim(0,1)
scatter(x,y, c='#ff0066')
scatter(X1,Y1, c='m')

# %%
X = len(X1)   # numero de puntos totales de la funcion
Y = len(x)  #numero de puntos totales
I = 6* float(X)/float(Y)

print I
# Out:
# 1.76208
