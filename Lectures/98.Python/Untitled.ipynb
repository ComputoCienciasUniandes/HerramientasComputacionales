# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def func(x,a,b,amp,x0,sigma):
    return a+b*x+amp*exp( -(x-x0)**2/sigma )

# %%
x=np.random.uniform(0.0, 10.0, 200)

# %%
param=[15.0,2.0,7.5,4.0,2.0]
y=func(x,*param)

# %%
scatter(x,y)

# %%
noise=random.normal(0.0,1.0,200)

# %%
y_noise=y+noise

# %%
from scipy.optimize import curve_fit

# %%
opt, cova =curve_fit(func,x,y_noise)
print opt
# Out:
# [ 15.03307663   2.00757965   7.35226615   4.00719531   1.99864133]

# %%
scatter(x,y_noise)
scatter(x,func(x,*opt))

# %%
def gaussiana(x, ampl, x_0, sigma):
    return ampl*exp( -(x-x_0)**2/sigma )
x_gau     = np.random.uniform(-4,4, 100)
noise = np.random.normal(0., 0.1, 100)
y_gau     =  gaussiana( x_gau, 8.0, 1.0, 0.5 ) + noise
p_opt, p_cov = curve_fit( gaussiana, x, y)
