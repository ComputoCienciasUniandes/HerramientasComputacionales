# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def gaussiana(x, a,b,ampl, x_0, sigma):
    return a+b*x+ampl*exp( -(x-x_0)**2/sigma )

# %%
from scipy.optimize import curve_fit

# %%
x     = np.random.uniform(-4,4, 100)
noise = np.random.normal(0., 0.1, 100)
y     =  gaussiana( x, 10.0,2.0,5.0, 1.0, 0.5 ) + noise

scatter(x,y, label="obs")
legend(loc=0)

# %%
p_opt, p_cov = curve_fit( gaussiana, x, y)

# %%
p_opt
# Out:
# array([ 10.01464069,   2.0044744 ,   5.01464732,   0.99514457,   0.49769884])

# %%
miau=loadtxt('datos.txt')

# %%
p, cova =curve_fit(gaussiana, miau[:,0], miau[:,1])

# %%
scatter(miau[:,0], miau[:,1])
scatter(miau[:,0], gaussiana(miau[:,0],*p),color='r')
