# %% [markdown]
# #1. Least Squares

# %% [markdown]
# El objetivo es encontrar las funciones que mas se ajusten a mis datos, para eso hay que minimizar una funcion que esta definida por
#
# $\sum (X_{measured}[i] - X_{predicted}[i])^2$ = Least Squares
#
# por lo tanto esta función se deriva para encontrar el minimo, tambien podria utilizarse alguno de los métodos para encontrar raices

# %% [markdown]
# #2. Polyfit

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Generating random data.

x = linspace(0, 10, 30)
y = 5*x+10

scatter(x, y, c='k', alpha=0.7, s=50)
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)

# %% [markdown]
# ### En la vida real dificilmente vamos a medir algo con tal exactitud, así que simulemos algo de ruido.

# %%
dy = randn(y.size)*5 # random.normal con sigma=1 centrada en cero, y.size==len(y)
y1 = y+dy
scatter(x, y1, c='k')
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)

# %%
fit =  polyfit(x, y1, 1)

print fit

plot(x, x*fit[0] + fit[1], linewidth='2.0', label="Fit")
plot(x, y, linewidth=2.0, c='r', label="Real")
scatter(x, y1, c='k', alpha=0.7)
legend(loc='best')
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
title("$\mathrm{Linear\ Regresion}$", fontsize=25)
# Out:
# [  4.82703008  11.99858365]

# %% [markdown]
# # 3. Coeficiente de correlación

# %% [markdown]
# ¿Que tan bien se aproxima mi modelo teórico a las mediciones?, Esto esta determinado por el coeficiente de terminación $R^2$
#
# $R^2 = 1 - \dfrac{EstimatedError}{Variance}$
#
# Si $R^2=1$ el modelo explica toda la variabilidad en mis datos, $si R^2=0$ no hay ninguna relación entre mi modelo y los datos.

# %%
def R2(xexp, xteo):
    EE = sum((xteo-xexp)**2)
    mean = sum(xexp)/(len(xexp))
    variance = sum((mean-xexp)**2)
    R2 = 1 - EE/variance
    return R2

# %%
yteo  = x*fit[0] + fit[1]
R2(y, yteo)
# Out:
# 0.99243694445088892

# %%
y = x**2 + x + 10
dy = randn(y.size)*10
y = y + dy

scatter(x, y, c='k')
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)

# %%
fit = polyfit(x, y, 2)

plot(x, fit[0]*x**2 + fit[1]*x + fit[2], linewidth=2.5)
scatter(x, y, c='k')
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
yteo = fit[0]*x**2 + fit[1]*x + fit[2]
R2(y, yteo)
# Out:
# 0.92353139293292419

# %% [markdown]
# #4. Fitting curves

# %%
from scipy.optimize import curve_fit

# %%
x = linspace(0, 2*pi, 40)
y = sin(x)

scatter(x, y)
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)

# %%
def sinfunc(x,a,b):
    return a*np.sin(x-b)
fitpars, covmat = curve_fit(sinfunc,x,y)

plot(x, sinfunc(x, fitpars[0], fitpars[1]), 'r-')
scatter(x, y)
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
print fitpars, covmat
# Out:
# [  1.00000000e+00   1.33864935e-09] [[  5.22920783e-20   7.81725769e-21]
#  [  7.81725769e-21   2.59975921e-20]]

# %%
x = linspace(0, 10, 30)
y = e**x
def expfunc(x,a,b):
    return a*e**(x-b)
fitpars, covmat = curve_fit(expfunc,x,y)

plot(x, expfunc(x, fitpars[0], fitpars[1]), 'r-')
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)
scatter(x, y)

# %%
x = linspace(0, 10, 30)
y = 5*x**3
def plfunc(x,a,b):
    return a*x**b
fitpars, covmat = curve_fit(plfunc,x,y)

plot(x, plfunc(x, fitpars[0], fitpars[1]), 'r-')
scatter(x, y)
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)

# %% [markdown]
# ##Intentemos una función un poco mas complicada!

# %%
x = linspace(0, 2*pi, 40)
y = sinh(x)*cos(x)

fitpars, covmat = curve_fit(plfunc,x,y)
plot(x, plfunc(x, fitpars[0], fitpars[1]), 'r-')
scatter(x, y)
xlabel("$\mathrm{x}$", fontsize=25)
ylabel("$\mathrm{y}$", fontsize=25)

# %% [markdown]
# #5. Exercise:
#
# Hacer ajustes de los archivos:
#
# data1.dat, data2.dat, data3.dat, data4.dat

# %% [markdown]
# #6. References
#
# ### 1. http://nbviewer.ipython.org/gist/keflavich/4042018
